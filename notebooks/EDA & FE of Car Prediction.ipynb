# %% [markdown]
# ## Car Price Prediction
#
# #### Problem Statement
#
# A Chinese automobile company Geely Auto aspires to enter the US market by setting up their manufacturing unit there and producing cars locally to give competition to their US and European counterparts.
#
# They have contracted an automobile consulting company to understand the factors on which the pricing of cars depends. Specifically, they want to understand the factors affecting the pricing of cars in the American market, since those may be very different from the Chinese market. The company wants to know:
#
# - Which variables are significant in predicting the price of a car
# - How well those variables describe the price of a car
#
# Based on various market surveys, the consulting firm has gathered a large dataset of different types of cars across the Americal market.
#
# ## Business Goal
#
# You are required to model the price of cars with the available independent variables. It will be used by the management to understand how exactly the prices vary with the independent variables. They can accordingly manipulate the design of the cars, the business strategy etc. to meet certain price levels. Further, the model will be a good way for management to understand the pricing dynamics of a new market.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dataset = pd.read_csv("CarPrice_Assignment.csv")

# %%
dataset.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %% [markdown]
# ## Data Cleaning

# %%
dataset[dataset.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [car_ID, symboling, CarName, fueltype, aspiration, doornumber, carbody, drivewheel, enginelocation, wheelbase, carlength, carwidth, carheight, curbweight, enginetype, cylindernumber, enginesize, fuelsystem, boreratio, stroke, compressionratio, horsepower, peakrpm, citympg, highwaympg, price]
# Index: []
#
# [0 rows x 26 columns]

# %%
dataset.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %% [markdown]
# ## There is no missing value present in the dataset

# %%
df = dataset

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df["doornumber"].value_counts()
# Out:
# doornumber
# four    115
# two      90
# Name: count, dtype: int64

# %%
df["doornumber"] = np.where(df["doornumber"].str.contains("four"),4,2)

# %%
df["doornumber"].value_counts()
# Out:
# doornumber
# 4    115
# 2     90
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    int32
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration  \
# 0       1          3        alfa-romero giulia      gas        std
# 1       2          3       alfa-romero stelvio      gas        std
# 2       3          1  alfa-romero Quadrifoglio      gas        std
# 3       4          2               audi 100 ls      gas        std
# 4       5          2                audi 100ls      gas        std
#
#    doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# 0           2  convertible        rwd          front       88.6  ...
# 1           2  convertible        rwd          front       88.6  ...
# 2           2    hatchback        rwd          front       94.5  ...
# 3           4        sedan        fwd          front       99.8  ...
# 4           4        sedan        4wd          front       99.4  ...
#
#    enginesize  fuelsystem  boreratio  stroke compressionratio horsepower  \
# ...

# %%
df.describe().T
# Out:
#                   count          mean          std      min      25%  \
# car_ID            205.0    103.000000    59.322565     1.00    52.00
# symboling         205.0      0.834146     1.245307    -2.00     0.00
# doornumber        205.0      3.121951     0.994966     2.00     2.00
# wheelbase         205.0     98.756585     6.021776    86.60    94.50
# carlength         205.0    174.049268    12.337289   141.10   166.30
# carwidth          205.0     65.907805     2.145204    60.30    64.10
# carheight         205.0     53.724878     2.443522    47.80    52.00
# curbweight        205.0   2555.565854   520.680204  1488.00  2145.00
# enginesize        205.0    126.907317    41.642693    61.00    97.00
# boreratio         205.0      3.329756     0.270844     2.54     3.15
# stroke            205.0      3.255415     0.313597     2.07     3.11
# compressionratio  205.0     10.142537     3.972040     7.00     8.60
# horsepower        205.0    104.117073    39.544167    48.00    70.00
# ...

# %% [markdown]
# ##  Exploratory Data Analysis

# %%
## drop CarName & car_ID Column
df_copy = df.drop(["CarName","car_ID"],axis=1)

# %%
df_copy.head()
# Out:
#    symboling fueltype aspiration  doornumber      carbody drivewheel  \
# 0          3      gas        std           2  convertible        rwd
# 1          3      gas        std           2  convertible        rwd
# 2          1      gas        std           2    hatchback        rwd
# 3          2      gas        std           4        sedan        fwd
# 4          2      gas        std           4        sedan        4wd
#
#   enginelocation  wheelbase  carlength  carwidth  ...  enginesize  fuelsystem  \
# 0          front       88.6      168.8      64.1  ...         130        mpfi
# 1          front       88.6      168.8      64.1  ...         130        mpfi
# 2          front       94.5      171.2      65.5  ...         152        mpfi
# 3          front       99.8      176.6      66.2  ...         109        mpfi
# 4          front       99.4      176.6      66.4  ...         136        mpfi
#
#   boreratio stroke  compressionratio horsepower  peakrpm  citympg  highwaympg  \
# ...

# %%
## categories in fueltype
df_copy["fueltype"].value_counts()
# Out:
# fueltype
# gas       185
# diesel     20
# Name: count, dtype: int64

# %%
## Encoding of the categories in fueltype
df_copy["fueltype"] = np.where(df_copy["fueltype"].str.contains("gas"),0,1)

# %%
df_copy.tail()
# Out:
#      symboling  fueltype aspiration  doornumber carbody drivewheel  \
# 200         -1         0        std           4   sedan        rwd
# 201         -1         0      turbo           4   sedan        rwd
# 202         -1         0        std           4   sedan        rwd
# 203         -1         1      turbo           4   sedan        rwd
# 204         -1         0      turbo           4   sedan        rwd
#
#     enginelocation  wheelbase  carlength  carwidth  ...  enginesize  \
# 200          front      109.1      188.8      68.9  ...         141
# 201          front      109.1      188.8      68.8  ...         141
# 202          front      109.1      188.8      68.9  ...         173
# 203          front      109.1      188.8      68.9  ...         145
# 204          front      109.1      188.8      68.9  ...         141
#
#      fuelsystem boreratio stroke  compressionratio horsepower  peakrpm  \
# 200        mpfi      3.78   3.15               9.5        114     5400
# ...

# %%
## Visualizing of price distribution
plt.figure(figsize=(20,10))

plt.subplot(1,2,1)
plt.title('Car Price Distribution Plot')
sns.distplot(df_copy.price)

plt.subplot(1,2,2)
plt.title('Car Price Sprade')
sns.boxplot(df_copy.price)
plt.show()
# Out:
# C:\Users\saroj\AppData\Local\Temp\ipykernel_114668\1830516053.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_copy.price)
# C:\Users\saroj\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
df_copy["price"].describe()
# Out:
# count      205.000000
# mean     13276.710571
# std       7988.852332
# min       5118.000000
# 25%       7788.000000
# 50%      10295.000000
# 75%      16503.000000
# max      45400.000000
# Name: price, dtype: float64

# %% [markdown]
# - The Distribution Plot shows that the data is right skiewed so most of the price is below 20000
# - 75% of price is below 16503 & left 25% of price in between 16503 to 45400

# %%
df_copy.head()
# Out:
#    symboling  fueltype aspiration  doornumber      carbody drivewheel  \
# 0          3         0        std           2  convertible        rwd
# 1          3         0        std           2  convertible        rwd
# 2          1         0        std           2    hatchback        rwd
# 3          2         0        std           4        sedan        fwd
# 4          2         0        std           4        sedan        4wd
#
#   enginelocation  wheelbase  carlength  carwidth  ...  enginesize  fuelsystem  \
# 0          front       88.6      168.8      64.1  ...         130        mpfi
# 1          front       88.6      168.8      64.1  ...         130        mpfi
# 2          front       94.5      171.2      65.5  ...         152        mpfi
# 3          front       99.8      176.6      66.2  ...         109        mpfi
# 4          front       99.4      176.6      66.4  ...         136        mpfi
#
# ...

# %%
df["fueltype"].value_counts()
# Out:
# fueltype
# gas       185
# diesel     20
# Name: count, dtype: int64

# %%
ax = sns.boxplot(x = "fueltype" , y = "price" , data = df)
ax.set(xlabel="Car Fuel Type" , ylabel="Price",title="Car Fuel Type VS Price")
# Out:
# C:\Users\saroj\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\saroj\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\saroj\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# [Text(0.5, 0, 'Car Fuel Type'),
#  Text(0, 0.5, 'Price'),
#  Text(0.5, 1.0, 'Car Fuel Type VS Price')]

# %%
def plot_price_effect(x):
    plt.figure(figsize=(20,10))
    plt.subplot(1,2,1)
    ax = sns.boxplot(x = x , y = "price" , data = df_copy)
    ax.set(xlabel=x , ylabel="Price",title= x+ " VS Price")
    plt.subplot(1,2,2)
    df11 = df_copy.groupby([x])["price"].mean().sort_values(ascending = False)
    df11.plot.bar(xlabel=x , ylabel="Price",title= x+ " VS Price")
    return df_copy[x].value_counts()

# %%
plot_price_effect('fueltype')   # 0 = gas & 1 = diesel
# Out:
# C:\Users\saroj\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\saroj\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\saroj\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# fueltype
# 0    185
# 1     20
# Name: count, dtype: int64

# %% [markdown]
# #### diesel car price is more high

# %%
plot_price_effect("aspiration")
# Out:
# C:\Users\saroj\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\saroj\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\saroj\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# aspiration
# std      168
# turbo     37
# Name: count, dtype: int64

# %% [markdown]
# ##### turbo is high price then std

# %%
plot_price_effect("doornumber")
# Out:
# C:\Users\saroj\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\saroj\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\saroj\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# doornumber
# 4    115
# 2     90
# Name: count, dtype: int64

# %% [markdown]
# ### - doornumber variable is not affecting the price much more there is no more difference bw 2 & 4 door so we delete this column

# %%
plot_price_effect('carbody')
# Out:
# C:\Users\saroj\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\saroj\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\saroj\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# carbody
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# ...

# %% [markdown]
# #### hardtop & convertible is almost same price

# %%
plot_price_effect('drivewheel')
# Out:
# C:\Users\saroj\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\saroj\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\saroj\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# drivewheel
# fwd    120
# rwd     76
# 4wd      9
# Name: count, dtype: int64

# %% [markdown]
# #### a very significant difference is shown in drivewheel spcially it is high in rwd drivewheel

# %%
plot_price_effect('enginelocation')
# Out:
# C:\Users\saroj\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\saroj\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\saroj\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# enginelocation
# front    202
# rear       3
# Name: count, dtype: int64

# %% [markdown]
# #### very few data points are different

# %%
plot_price_effect('enginetype')
# Out:
# C:\Users\saroj\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\saroj\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\saroj\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# enginetype
# ohc      148
# ohcf      15
# ohcv      13
# dohc      12
# l         12
# rotor      4
# dohcv      1
# ...

# %% [markdown]
# #### there is a few price difference bw each enginetype

# %%
plot_price_effect('cylindernumber')
# Out:
# C:\Users\saroj\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\saroj\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\saroj\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# cylindernumber
# four      159
# six        24
# five       11
# eight       5
# two         4
# three       1
# twelve      1
# ...

# %% [markdown]
# #### there is high price in eight cylindernumber & three is less cylindernumber

# %%
## drop doornumber columns
df_copy = df_copy.drop(["doornumber"],axis=1)

# %%
df_copy.head()
# Out:
#    symboling  fueltype aspiration      carbody drivewheel enginelocation  \
# 0          3         0        std  convertible        rwd          front
# 1          3         0        std  convertible        rwd          front
# 2          1         0        std    hatchback        rwd          front
# 3          2         0        std        sedan        fwd          front
# 4          2         0        std        sedan        4wd          front
#
#    wheelbase  carlength  carwidth  carheight  ...  enginesize fuelsystem  \
# 0       88.6      168.8      64.1       48.8  ...         130       mpfi
# 1       88.6      168.8      64.1       48.8  ...         130       mpfi
# 2       94.5      171.2      65.5       52.4  ...         152       mpfi
# 3       99.8      176.6      66.2       54.3  ...         109       mpfi
# 4       99.4      176.6      66.4       54.3  ...         136       mpfi
#
#   boreratio  stroke compressionratio  horsepower  peakrpm  citympg  \
# ...

# %%
## Encoding of the categories in aspiration
df_copy["aspiration"] = np.where(df_copy["aspiration"].str.contains("std"),0,1)   ## std = 0  & turbo = 1

# %%
df_copy.tail()
# Out:
#      symboling  fueltype  aspiration carbody drivewheel enginelocation  \
# 200         -1         0           0   sedan        rwd          front
# 201         -1         0           1   sedan        rwd          front
# 202         -1         0           0   sedan        rwd          front
# 203         -1         1           1   sedan        rwd          front
# 204         -1         0           1   sedan        rwd          front
#
#      wheelbase  carlength  carwidth  carheight  ...  enginesize fuelsystem  \
# 200      109.1      188.8      68.9       55.5  ...         141       mpfi
# 201      109.1      188.8      68.8       55.5  ...         141       mpfi
# 202      109.1      188.8      68.9       55.5  ...         173       mpfi
# 203      109.1      188.8      68.9       55.5  ...         145        idi
# 204      109.1      188.8      68.9       55.5  ...         141       mpfi
#
#     boreratio  stroke compressionratio  horsepower  peakrpm  citympg  \
# ...

# %%
## Encoding of the categories in enginelocation
df_copy["enginelocation"] = np.where(df_copy["enginelocation"].str.contains("front"),0,1)   ## front = 0  & rear = 1

# %%
df_copy["enginelocation"].value_counts()
# Out:
# enginelocation
# 0    202
# 1      3
# Name: count, dtype: int64

# %%
df_copy.head()
# Out:
#    symboling  fueltype  aspiration      carbody drivewheel  enginelocation  \
# 0          3         0           0  convertible        rwd               0
# 1          3         0           0  convertible        rwd               0
# 2          1         0           0    hatchback        rwd               0
# 3          2         0           0        sedan        fwd               0
# 4          2         0           0        sedan        4wd               0
#
#    wheelbase  carlength  carwidth  carheight  ...  enginesize fuelsystem  \
# 0       88.6      168.8      64.1       48.8  ...         130       mpfi
# 1       88.6      168.8      64.1       48.8  ...         130       mpfi
# 2       94.5      171.2      65.5       52.4  ...         152       mpfi
# 3       99.8      176.6      66.2       54.3  ...         109       mpfi
# 4       99.4      176.6      66.4       54.3  ...         136       mpfi
#
#   boreratio  stroke compressionratio  horsepower  peakrpm  citympg  \
# ...

# %%
## carbody drivewheel  enginetype   cylindernumber  fuelsystem

# %%
# from sklearn.preprocessing import OneHotEncoder
# encoder = OneHotEncoder()
# encoded = encoder.fit_transform(df_copy[['carbody']])
# encoded_df = pd.DataFrame(encoded.toarray(),columns=encoder.get_feature_names_out()).astype(int)
# df_copy = pd.concat([encoded_df,df_copy],axis=1)
# df_copy.drop(['carbody'],axis=1,inplace=True)

# %%
#df_copy.head()

# %%
# def encode_value(x,df):
#     encoder = OneHotEncoder()
#     encoded = encoder.fit_transform(df[[x]])
#     encoded_df = pd.DataFrame(encoded.toarray(),columns=encoder.get_feature_names_out()).astype(int)
#     df = pd.concat([df,encoded_df],axis=1)
#     df.drop([x],axis=1,inplace=True)
#     return df

# %%
# from sklearn.preprocessing import OneHotEncoder
# encoder = OneHotEncoder()
# encoded = encoder.fit_transform(df_copy[['drivewheel']])
# encoded_df = pd.DataFrame(encoded.toarray(),columns=encoder.get_feature_names_out()).astype(int)
# df_copy = pd.concat([encoded_df,df_copy],axis=1)
# df_copy.drop(['drivewheel'],axis=1,inplace=True)

# %%
# df_copy.head()

# %%
# from sklearn.preprocessing import OneHotEncoder
# encoder = OneHotEncoder()
# encoded = encoder.fit_transform(df_copy[['enginetype']])
# encoded_df = pd.DataFrame(encoded.toarray(),columns=encoder.get_feature_names_out()).astype(int)
# df_copy = pd.concat([encoded_df,df_copy],axis=1)
# df_copy.drop(['enginetype'],axis=1,inplace=True)

# %%
# df_copy.head()

# %%
# from sklearn.preprocessing import OneHotEncoder
# encoder = OneHotEncoder()
# encoded = encoder.fit_transform(df_copy[['cylindernumber']])
# encoded_df = pd.DataFrame(encoded.toarray(),columns=encoder.get_feature_names_out()).astype(int)
# df_copy = pd.concat([encoded_df,df_copy],axis=1)
# df_copy.drop(['cylindernumber'],axis=1,inplace=True)

# %%
# df_copy.head()

# %%
# from sklearn.preprocessing import OneHotEncoder
# encoder = OneHotEncoder()
# encoded = encoder.fit_transform(df_copy[['fuelsystem']])
# encoded_df = pd.DataFrame(encoded.toarray(),columns=encoder.get_feature_names_out()).astype(int)
# df_copy = pd.concat([encoded_df,df_copy],axis=1)
# df_copy.drop(['fuelsystem'],axis=1,inplace=True)

# %%
# df_copy.head()

# %%
## Let ave the cleaned dataset which is use for ML prediction
#df_copy.to_csv("CarPrice_Cleaned_Data.csv",index=False)

# %%
df_copy.head()
# Out:
#    symboling  fueltype  aspiration      carbody drivewheel  enginelocation  \
# 0          3         0           0  convertible        rwd               0
# 1          3         0           0  convertible        rwd               0
# 2          1         0           0    hatchback        rwd               0
# 3          2         0           0        sedan        fwd               0
# 4          2         0           0        sedan        4wd               0
#
#    wheelbase  carlength  carwidth  carheight  ...  enginesize fuelsystem  \
# 0       88.6      168.8      64.1       48.8  ...         130       mpfi
# 1       88.6      168.8      64.1       48.8  ...         130       mpfi
# 2       94.5      171.2      65.5       52.4  ...         152       mpfi
# 3       99.8      176.6      66.2       54.3  ...         109       mpfi
# 4       99.4      176.6      66.4       54.3  ...         136       mpfi
#
#   boreratio  stroke compressionratio  horsepower  peakrpm  citympg  \
# ...

# %%
## drop carbody drivewheel  enginetype   cylindernumber  fuelsystem columns
df_copy = df_copy.drop(["carbody","drivewheel","enginetype","cylindernumber","fuelsystem"],axis=1)

# %%
df_copy.head()
# Out:
#    symboling  fueltype  aspiration  enginelocation  wheelbase  carlength  \
# 0          3         0           0               0       88.6      168.8
# 1          3         0           0               0       88.6      168.8
# 2          1         0           0               0       94.5      171.2
# 3          2         0           0               0       99.8      176.6
# 4          2         0           0               0       99.4      176.6
#
#    carwidth  carheight  curbweight  enginesize  boreratio  stroke  \
# 0      64.1       48.8        2548         130       3.47    2.68
# 1      64.1       48.8        2548         130       3.47    2.68
# 2      65.5       52.4        2823         152       2.68    3.47
# 3      66.2       54.3        2337         109       3.19    3.40
# 4      66.4       54.3        2824         136       3.19    3.40
#
#    compressionratio  horsepower  peakrpm  citympg  highwaympg    price
# ...

# %%
# Let ave the cleaned dataset which is use for ML prediction
df_copy.to_csv("CarPrice_Cleaned_Data.csv",index=False)

# %%
df_copy.shape
# Out:
# (205, 18)

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   symboling         205 non-null    int64
#  1   fueltype          205 non-null    int32
#  2   aspiration        205 non-null    int32
#  3   enginelocation    205 non-null    int32
#  4   wheelbase         205 non-null    float64
#  5   carlength         205 non-null    float64
#  6   carwidth          205 non-null    float64
#  7   carheight         205 non-null    float64
#  8   curbweight        205 non-null    int64
#  9   enginesize        205 non-null    int64
#  10  boreratio         205 non-null    float64
#  11  stroke            205 non-null    float64
#  12  compressionratio  205 non-null    float64
#  13  horsepower        205 non-null    int64
#  14  peakrpm           205 non-null    int64
#  15  citympg           205 non-null    int64
# ...

# %%
## Plot desnity plot for all features
#plt.style.use('seaborn')
df_copy.hist(bins=50,figsize=(20,15))
plt.show()
